# %%
import tifffile as tiff
import numpy as np
# !pip install tifffile


# Replace 'path_to_your_file.tif' with the actual path to your TIFF file
tif_file_path = r'D:\A透视地球\森林圈层展示数据\forest_type.tif'

# Read the TIFF file
image = tiff.imread(tif_file_path)

# Display the image shape
print("Image shape:", image.shape)
# Out:
# Image shape: (2268, 2243)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt

# Display the image
plt.imshow(image, cmap='gray')
plt.title('Forest Type Image')
plt.axis('off')  # Hide the axis
plt.show()

# %%
image.min()
# Out:
# np.uint8(10)

# %%
image.max()
# Out:
# np.uint8(255)

# %%
np.linspace(108,111,2268)
# Out:
# array([108.        , 108.00132333, 108.00264667, ..., 110.99735333,
#        110.99867667, 111.        ])

# %%
np.linspace(20,18,2243)
# Out:
# array([20.        , 19.99910794, 19.99821588, ..., 18.00178412,
#        18.00089206, 18.        ])

# %%
len(image.tolist()[0])
# Out:
# 2243
